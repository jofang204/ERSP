# %%
import sys
import math
import re
import os

def parse(fname):
    for l in open(fname):
        yield str(l) 

data = parse("./GSE2109_family.soft")

# %%
dict= {}
sample_id = 0
header = []
samples =[]
header_f = 0

# %%
for line in data:
    if "^SAMPLE" in line:
        sample_id = line.rstrip('\n').split(' = ')[-1]
        samples.append(sample_id)
        dict[sample_id] = []
        if header_f == 0:
            header.append(sample_id)
    elif "!Sample_type" in line:
        dict[sample_id].append(line.rstrip('\n').split(' = ')[-1])
        if header_f == 0:
            header.append("sample_type")
    elif "!Sample_title" in line:
        dict[sample_id].append(line.rstrip('\n').split(' = ')[-1])
        if header_f == 0:
            header.append("sample_title")
    elif "Sample_source_name_ch1" in line:
        dict[sample_id].append(line.rstrip('\n').split(' = ')[-1])
        if header_f == 0:
            header.append("source_name")
    elif "!Sample_description = Patient Age: " in line:
        dict[sample_id].append(line.rstrip('\n').split(': ')[-1])
        if header_f == 0:
            header.append("patient_age")
    elif "!Sample_description = Gender: " in line:
        dict[sample_id].append(line.rstrip('\n').split(': ')[-1])
        if header_f == 0:
            header.append("gender")
    elif "!Sample_description = Ethnic Background: " in line:
        dict[sample_id].append(line.rstrip('\n').split(': ')[-1])
        if header_f == 0:
            header.append("ethnic background")
    elif "!Sample_description = Primary Site: " in line:
        dict[sample_id].append(line.rstrip('\n').split(': ')[-1])
        if header_f == 0:
            header.append("primary_site")
    elif "!Sample_description = Histology: " in line:
        dict[sample_id].append(line.rstrip('\n').split(': ')[-1])
        if "Metastatic" in line:
            dict[sample_id].append("Metastatic")
        else:
            dict[sample_id].append("Non-metastatic")
        if header_f == 0:
            header.append("histology")
            header.append("Cancer_type")
            header_f = 1

# %%
header
# Out:
# ['GSM38051',
#  'sample_title',
#  'sample_type',
#  'source_name',
#  'patient_age',
#  'gender',
#  'ethnic background',
#  'primary_site',
#  'histology']

# %%
dict
# Out:
# {'GSM117689': ['Lung - 161511',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Female',
#   'African-American',
#   'Lung',
#   'Neuroendocrine carcinoma',
#   'Non-metastatic'],
#  'GSM117688': ['Axillary Lymph Node - 161469',
#   'RNA',
#   'Axillary Lymph Node',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Metastatic Ductal Carcinoma',
#   'Metastatic'],
#  'GSM117687': ['Breast - 161462',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117686': ['Breast - 161435',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117685': ['Breast - 161430',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117684': ['Rectosigmoid - 152491',
#   'RNA',
#   'Rectosigmoid',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117683': ['Rectum - 152490',
#   'RNA',
#   'Rectum',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Rectum',
#   'Carcinoma in situ arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM117682': ['Kidney - 152489',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional(clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM117681': ['Colon - 152488',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM117680': ['Kidney - 152487',
#   'RNA',
#   'Kidney',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102508': ['Rib - 136912',
#   'RNA',
#   'Rib',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Unknown Primary'],
#  'GSM102509': ['Uterus - 136913',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Adenosquamous carcinoma',
#   'Non-metastatic'],
#  'GSM102506': ['Breast - 133638',
#   'RNA',
#   'Breast',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM102507': ['Lung - 136910',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM102504': ['Omentum - 129709',
#   'RNA',
#   'Omentum',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Adenocarcinoma',
#   'Metastatic'],
#  'GSM102505': ['Lung - 132229',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Bronchioloalveolar carcinoma',
#   'Non-metastatic'],
#  'GSM102502': ['Breast - 129702',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM102503': ['Liver - 129708',
#   'RNA',
#   'Liver',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Liver'],
#  'GSM102500': ['Kidney - 129694',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102501': ['Colon - 129700',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM102432': ['Kidney - 101119',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102433': ['Kidney - 101126',
#   'RNA',
#   'Kidney',
#   '30-40',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM76569': ['Pelvic mass - 33795',
#   'RNA',
#   'Pelvic mass',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Malignant mixed Mullerian tumor',
#   'Non-metastatic'],
#  'GSM76568': ['Kidney - 33794',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102436': ['Colon - 101129',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM102437': ['Bladder - 101130',
#   'RNA',
#   'Bladder',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Urinary Bladder',
#   'Urothelial (transitional cell) carcinoma',
#   'Non-metastatic'],
#  'GSM102434': ['Bladder - 101127',
#   'RNA',
#   'Bladder',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Urinary Bladder',
#   'Urothelial (transitional cell) carcinoma',
#   'Non-metastatic'],
#  'GSM102435': ['Prostate - 101128',
#   'RNA',
#   'Prostate',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM76563': ['Breast - 31593',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76562': ['Stomach - 31589',
#   'RNA',
#   'Stomach',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Stomach',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76561': ['Breast - 31588',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76560': ['Breast - 31586',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76567': ['Ovary - 33793',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM76566': ['Breast - 33792',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76565': ['Rectosigmoid - 33791',
#   'RNA',
#   'Rectosigmoid',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Fallopian Tube',
#   'Metastatic Papillary serous carcinoma',
#   'Metastatic'],
#  'GSM76564': ['Breast - 31883',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM231983': ['Uterus - 415963',
#   'RNA',
#   'Uterus',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM46933': ['Breast - 29303',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM46932': ['Abdominal Wall Fascia - 29293',
#   'RNA',
#   'Abdominal wall fascia',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Metastatic Endometrioid carcinoma',
#   'Metastatic'],
#  'GSM46931': ['Colon - 29291',
#   'RNA',
#   'Colon',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM46930': ['Colon - 29287',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM46937': ['Uterine Corpus - 31814',
#   'RNA',
#   'Uterine Corpus',
#   '50-60',
#   'Female',
#   'American Indian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM46936': ['Lung - 31812',
#   'RNA',
#   'Lung',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM46935': ['Omentum - 31810',
#   'RNA',
#   'Omentum',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Carcinoma',
#   'Metastatic'],
#  'GSM46934': ['Breast - 29313',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM46939': ['Kidney - 31818',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM46938': ['Breast - 31816',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Metaplastic Carcinoma',
#   'Non-metastatic'],
#  'GSM152587': ['Lymph Node - 143663',
#   'RNA',
#   'Lymph node',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Cervix Uteri',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM152586': ['Pelvic tumor - 143653',
#   'RNA',
#   'Pelvic tumor',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Endometrioid adenocarcinoma',
#   'Metastatic'],
#  'GSM152585': ['Breast - 133639',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM152584': ['Liver - 133637',
#   'RNA',
#   'Liver',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM152583': ['Pelvic mass - 129671',
#   'RNA',
#   'Pelvic mass',
#   '40-50',
#   'Female',
#   'Asian',
#   'Ovarian remnant'],
#  'GSM152582': ['Colon - 129670',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152581': ['Ovary - 129669',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152580': ['Cervix Uteri - 129668',
#   'RNA',
#   'Cervix Uteri',
#   '20-30',
#   'Female',
#   'Caucasian',
#   'Cervix Uteri',
#   'Squamous cell carcinoma, spindle cell type',
#   'Non-metastatic'],
#  'GSM152589': ['Omentum - 144571',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM152588': ['Lymph Node - 143669',
#   'RNA',
#   'Lymph node',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Eye, NOS',
#   'Metastatic Malignant melanoma, NOS',
#   'Metastatic'],
#  'GSM137942': ['Colon - 187218',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM137943': ['Breast - 187219',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM137940': ['GI Tract Connective Tissue - 184856',
#   'RNA',
#   'GI Tract Connective Tissue',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Stomach'],
#  'GSM137941': ['Kidney - 184860',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional(clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM137946': ['Kidney - 187225',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney'],
#  'GSM137947': ['Colon - 187229',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM137944': ['Breast - 187220',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM137945': ['Lung - 187222',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM137948': ['Kidney - 187230',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional(clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM137949': ['Colon - 187232',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203656': ['Kidney - 228543',
#   'RNA',
#   'Kidney',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Renal Pelvis',
#   'Urothelial (transitional cell) carcinoma',
#   'Non-metastatic'],
#  'GSM301703': ['Omentum - 443480',
#   'RNA',
#   'Omentum',
#   '50-59',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301702': ['Rectosigmoid - 443479',
#   'RNA',
#   'Rectosigmoid',
#   '50-59',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301701': ['Prostate - 443469',
#   'RNA',
#   'Prostate',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM301700': ['Abdominal Wall Soft Tissue - 443462',
#   'RNA',
#   'Abdominal Wall Soft Tissue',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Peritoneum'],
#  'GSM301707': ['Uterus - 443489',
#   'RNA',
#   'Uterus',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301706': ['Sigmoid Colon - 443483',
#   'RNA',
#   'Sigmoid Colon',
#   '80-89',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179799': ['Ovary - 199400',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Adenocarcinoma with mixed subtypes',
#   'Non-metastatic'],
#  'GSM179798': ['Ovary - 199399',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Carcinoma, NOS',
#   'Non-metastatic'],
#  'GSM179795': ['Colon - 199354',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179794': ['Uterus - 195194',
#   'RNA',
#   'Uterus',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM179797': ['Kidney - 199394',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM179796': ['Connective tissue of abdomen - 199376',
#   'RNA',
#   'Connective tissue of abdomen',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Connective tissue of abdomen'],
#  'GSM179791': ['Breast - 193026',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM179790': ['Prostate - 193004',
#   'RNA',
#   'Prostate',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM179793': ['Colon - 195191',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179792': ['Prostate - 193028',
#   'RNA',
#   'Prostate',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM152734': ['Uterus - 241184',
#   'RNA',
#   'Uterus',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM152735': ['Ovary - 241187',
#   'RNA',
#   'Ovary',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary mucinous cystadenocarcinoma',
#   'Non-metastatic'],
#  'GSM152736': ['Parotid gland - 241188',
#   'RNA',
#   'Parotid gland',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Carcinoma of Skin',
#   'Metastatic Squamous cell carcinoma, NOS',
#   'Metastatic'],
#  'GSM152737': ['Uterus - 241191',
#   'RNA',
#   'Uterus',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM152730': ['Colon - 241168',
#   'RNA',
#   'Colon',
#   '40-50',
#   'Female',
#   'African-American',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152731': ['Uterus - 241169',
#   'RNA',
#   'Uterus',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM152732': ['Urinary Bladder - 241178',
#   'RNA',
#   'Urinary Bladder',
#   '80-90',
#   'Male',
#   'Caucasian',
#   'Urinary Bladder',
#   'Small cell carcinoma, NOS',
#   'Non-metastatic'],
#  'GSM152733': ['Ovary - 241181',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Endometrioid Carcinoma',
#   'Non-metastatic'],
#  'GSM152738': ['Uterus - 241197',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Adenosquamous carcinoma',
#   'Non-metastatic'],
#  'GSM152739': ['Ovary - 241198',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium'],
#  'GSM277736': ['Pancreas - 443468',
#   'RNA',
#   'Pancreas',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Exocrine Pancreas',
#   'Mucinous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301691': ['Rectosigmoid - 438176',
#   'RNA',
#   'Rectosigmoid',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301690': ['breast - 438172',
#   'RNA',
#   'breast',
#   '30-39',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Metastatic Ductal Carcinoma',
#   'Metastatic'],
#  'GSM301693': ['LUL Lung - 440426',
#   'RNA',
#   'LUL Lung',
#   '50-59',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM301692': ['Stomach - 438185',
#   'RNA',
#   'Stomach',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Soft Tissue Stomach',
#   'Spindle Cell Sarcoma',
#   'Non-metastatic'],
#  'GSM301695': ['Ovary - 440437',
#   'RNA',
#   'Ovary',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Mixed endometrioid and papillary serous adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301694': ['Pleural Nodule - 440429',
#   'RNA',
#   'Pleural Nodule',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM301697': ['Kidney - 440441',
#   'RNA',
#   'Kidney',
#   '70-79',
#   'Male',
#   'African-American',
#   'Kidney',
#   'Clear cell adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301696': ['Ovary - 440440',
#   'RNA',
#   'Ovary',
#   '40-49',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301699': ['Ovary - 443454',
#   'RNA',
#   'Ovary',
#   '40-49',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Endometrioid adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301698': ['Uterus - 440445',
#   'RNA',
#   'Uterus',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Malignant mixed Mullerian tumor',
#   'Non-metastatic'],
#  'GSM203689': ['Soft Tissue of Neck - 308701',
#   'RNA',
#   'Soft Tissue of Neck',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Unknown'],
#  'GSM203688': ['Colon - 308699',
#   'RNA',
#   'Colon',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203683': ['Thyroid - 290726',
#   'RNA',
#   'Thyroid',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Thyroid',
#   'Papillary carcinoma, follicular variant',
#   'Non-metastatic'],
#  'GSM203682': ['Jejunum - 290725',
#   'RNA',
#   'Jejunum',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Melanoma of Skin',
#   'Metastatic Malignant melanoma, NOS',
#   'Metastatic'],
#  'GSM203681': ['Ileum - 290715',
#   'RNA',
#   'Ileum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ileum'],
#  'GSM203680': ['Uterus - 286673',
#   'RNA',
#   'Uterus',
#   '70-80',
#   'Female',
#   'African-American',
#   'Endometrium',
#   'Serous adenocarcinoma (papillary serous)',
#   'Non-metastatic'],
#  'GSM203687': ['Colon - 308695',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM203686': ['Ovary - 308691',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Metastatic Endometrioid carcinoma',
#   'Metastatic'],
#  'GSM203685': ['Uterus - 298074',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM203684': ['Colon - 290734',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM46840': ['Ovary - 1353',
#   'RNA',
#   'L Adnexa',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM53067': ['Endometrium - 1637',
#   'RNA',
#   'Endometrium',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53066': ['Ovary - 1636',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Unknown',
#   'Metastatic Malignant Neoplasm, NOS',
#   'Metastatic'],
#  'GSM53065': ['Endometrium - 1634',
#   'RNA',
#   'Endometrium',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53064': ['Kidney - 1633',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM53063': ['Ovary - 1323',
#   'RNA',
#   'Ovary',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Endometrioid Carcinoma',
#   'Non-metastatic'],
#  'GSM53062': ['Kidney - 1320',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Hispanic',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM53061': ['Prostate - 1317',
#   'RNA',
#   'Prostate',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM53060': ['Kidney - 1296',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM46847': ['Kidney - 22198',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM53069': ['Ovary - 1643',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Serous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM53068': ['Ovary - 1639',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM203739': ['Pelvic mass - 341551',
#   'RNA',
#   'Pelvic mass',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Adenocarcinoma',
#   'Metastatic'],
#  'GSM203738': ['Urinary bladder - 341550',
#   'RNA',
#   'Urinary bladder',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Urinary Bladder',
#   'Papillary transitional cell carcinoma',
#   'Non-metastatic'],
#  'GSM277738': ['Omentum - 443473',
#   'RNA',
#   'Omentum',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Fallopian Tube',
#   'Papillary serous adenocarcinoma',
#   'Non-metastatic'],
#  'GSM46846': ['Breast - 21808',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'African-American',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM353942': ['Cecum - 487435',
#   'RNA',
#   'Cecum',
#   '70-79',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM353943': ['Uterus - 487457',
#   'RNA',
#   'Uterus',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Corpus Uteri',
#   'Carcinosarcoma',
#   'Non-metastatic'],
#  'GSM353940': ['Prostate - 486153',
#   'RNA',
#   'Prostate',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM353941': ['Uterus - 486154',
#   'RNA',
#   'Uterus',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Mixed Cell Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53119': ['Corpus Uteri - 29301',
#   'RNA',
#   'Corpus Uteri',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Malignant mixed Mullerian tumor',
#   'Non-metastatic'],
#  'GSM53118': ['Ovary - 29299',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Carcinoid tumor with atypical features',
#   'Non-metastatic'],
#  'GSM46845': ['Colon - 2049',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203731': ['Colon - 341526',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Carcinoma in situ arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM53113': ['Colon - 29281',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53112': ['Cervix - 29273',
#   'RNA',
#   'Cervix',
#   '20-30',
#   'Female',
#   'Caucasian',
#   'Cervix',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM53111': ['Colon - 29267',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Metastatic Mucinous adenocarcinoma',
#   'Metastatic'],
#  'GSM53110': ['Breast - 29245',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53117': ['Urinary Bladder - 29295',
#   'RNA',
#   'Urinary Bladder',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Urinary Bladder',
#   'Urothelial (transitional cell) carcinoma',
#   'Non-metastatic'],
#  'GSM53116': ['Soft Tissue of Knee - 29289',
#   'RNA',
#   'Soft Tissue of Knee',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Soft Tissue of Knee',
#   'Ewings sarcoma/primitive neuroectodermal tumor',
#   'Non-metastatic'],
#  'GSM53115': ['Breast - 29285',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53114': ['Prostate - 29283',
#   'RNA',
#   'Prostate',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM231974': ['Ovary - 409603',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Serous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM231975': ['Ovary - 409605',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM231976': ['Breast - 409606',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM231977': ['Uterus - 409608',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM231970': ['Esophagus - 407830',
#   'RNA',
#   'Esophagus',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Esophagus'],
#  'GSM231971': ['Colon - 409599',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM231972': ['Kidney - 409601',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM231973': ['Thyroid - 409602',
#   'RNA',
#   'Thyroid',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Thyroid',
#   'Papillary carcinoma, follicular variant',
#   'Non-metastatic'],
#  'GSM231978': ['Prostate - 409625',
#   'RNA',
#   'Prostate',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM231979': ['Prostate - 409628',
#   'RNA',
#   'Prostate',
#   '40-50',
#   'Male',
#   'African-American',
#   'Prostate',
#   'Adenocarcinoma, Acinar Type',
#   'Non-metastatic'],
#  'GSM46844': ['Lung - 1503',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Bladder',
#   'Metastatic non-small cell carcinoma',
#   'Metastatic'],
#  'GSM38110': ['Breast - 8272',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117690': ['Branchial Cleft Cyst - 161512',
#   'RNA',
#   'Branchial Cleft Cyst',
#   '60-70',
#   'Male',
#   'Head & Neck, NOS'],
#  'GSM117691': ['Endometrium - 161513',
#   'RNA',
#   'Endometrium',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Clear cell adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117692': ['Breast - 161516',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117693': ['Parametrial Implant - 161518',
#   'RNA',
#   'Parametrial Implant',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Metastatic Papillary Serous Carcinoma',
#   'Metastatic'],
#  'GSM76488': ['Lung - 20275',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Lung',
#   'Bronchioloalveolar carcinoma',
#   'Non-metastatic'],
#  'GSM76489': ['Ovary - 20284',
#   'RNA',
#   'Ovary',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Serous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM117696': ['Ovary - 161524',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117697': ['Endometrium - 161527',
#   'RNA',
#   'Endometrium',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM117698': ['Omentum - 161529',
#   'RNA',
#   'Omentum',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Peritoneum'],
#  'GSM117699': ['Rectosigmoid - 170822',
#   'RNA',
#   'Rectosigmoid',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma in adenomatous polyp',
#   'Non-metastatic'],
#  'GSM76486': ['Breast - 1005',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76487': ['Endometrium - 1039',
#   'RNA',
#   'Endometrium',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM102430': ['Uterus - 101099',
#   'RNA',
#   'Uterus',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM102533': ['Colon - 161432',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM102532': ['Soft Tissue Thigh - 157425',
#   'RNA',
#   'Soft Tissue Thigh',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Soft Tissue Sarcoma',
#   'Pleomorphic sarcoma',
#   'Non-metastatic'],
#  'GSM102531': ['Liver - 152480',
#   'RNA',
#   'Liver',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM102431': ['Colon - 101116',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM102537': ['Kidney - 161463',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102536': ['Breast - 161439',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM102535': ['Rectosigmoid - 161438',
#   'RNA',
#   'Rectosigmoid',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM102534': ['Breast - 161433',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM102539': ['Rectosigmoid - 161466',
#   'RNA',
#   'Rectosigmoid',
#   '80-90',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM102538': ['Ovary - 161465',
#   'RNA',
#   'Ovary',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Malignant mixed muellerian tumor',
#   'Non-metastatic'],
#  'GSM231981': ['Ovary - 415960',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Endometrioid Carcinoma',
#   'Non-metastatic'],
#  'GSM231980': ['Ovary - 409630',
#   'RNA',
#   'Ovary',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary serous tumor of low malignant potential',
#   'Non-metastatic'],
#  'GSM102438': ['Kidney - 101133',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM102439': ['Breast - 101135',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Metaplastic squamous carcinoma',
#   'Non-metastatic'],
#  'GSM231985': ['Thyroid - 415971',
#   'RNA',
#   'Thyroid',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Thyroid',
#   'Papillary carcinoma',
#   'Non-metastatic'],
#  'GSM231984': ['Kidney - 415970',
#   'RNA',
#   'Kidney',
#   '80-90',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM231987': ['Rectum - 416801',
#   'RNA',
#   'Rectum',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Rectum',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM231986': ['Kidney - 415976',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM277737': ['Omentum - 443471',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76558': ['Kidney - 31581',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM76559': ['Renal Pelvis - 31585',
#   'RNA',
#   'Renal Pelvis',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Renal Pelvis',
#   'Urothelial (transitional cell) carcinoma',
#   'Non-metastatic'],
#  'GSM76556': ['Breast - 31577',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76557': ['Parotid Gland - 31580',
#   'RNA',
#   'Parotid Gland',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Parotid Gland'],
#  'GSM76554': ['Ovary - 31574',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM76555': ['Colon - 31575',
#   'RNA',
#   'Colon',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76552': ['Breast - 31570',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76553': ['Prostate - 31573',
#   'RNA',
#   'Prostate',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, Acinar Type',
#   'Non-metastatic'],
#  'GSM76550': ['Appendix - 22206',
#   'RNA',
#   'Appendix',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Appendix',
#   'Signet Ring Cell Carcinoma',
#   'Non-metastatic'],
#  'GSM76551': ['Kidney - 28971',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM46906': ['Omentum - 23956',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Fallopian Tube',
#   'Metastatic Adenocarcinoma, NOS',
#   'Metastatic'],
#  'GSM46907': ['Peritoneum - 23960',
#   'RNA',
#   'Soft Tissue Abdominal Mass',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Carcinoma, NOS',
#   'Metastatic'],
#  'GSM46904': ['Lung - 23952',
#   'RNA',
#   'Lung',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Bronchioloalveolar carcinoma',
#   'Non-metastatic'],
#  'GSM46905': ['Breast - 23954',
#   'RNA',
#   'Breast',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM46902': ['Omentum - 23948',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Unknown',
#   'Metastatic Papillary Serous Adenocarcinoma',
#   'Metastatic'],
#  'GSM46903': ['Lung - 23950',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'GI Tract, NOS'],
#  'GSM46900': ['Breast - 23944',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma In-situ (DCIS) with focal Comedo Carcinoma',
#   'Non-metastatic'],
#  'GSM46901': ['Rectosigmoid Colon - 23946',
#   'RNA',
#   'Rectosigmoid Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152590': ['Breast - 151607',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Other',
#   'Unknown',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM152591': ['Colon - 151618',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152592': ['Lung - 151625',
#   'RNA',
#   'Lung',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM152593': ['Kidney - 152470',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney'],
#  'GSM152594': ['Lung - 154218',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM152595': ['Stomach - 161522',
#   'RNA',
#   'Stomach',
#   '90-100',
#   'Female',
#   'Caucasian',
#   'Stomach',
#   'Tubular adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152596': ['Ovary - 161525',
#   'RNA',
#   'Ovary',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM152597': ['Uterus - 161530',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM46832': ['Colon - 1315',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Carcinoma in situ arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM46833': ['Lung - 1316',
#   'RNA',
#   'Lung',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM46830': ['Ovary - 1311',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Endometrioid Carcinoma',
#   'Non-metastatic'],
#  'GSM46831': ['Ovary - 1313',
#   'RNA',
#   'Ovary',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM46836': ['Breast - 1322',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Intraductal Carcinoma',
#   'Non-metastatic'],
#  'GSM46837': ['Prostate - 1324',
#   'RNA',
#   'Prostate',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, Acinar Type',
#   'Non-metastatic'],
#  'GSM46834': ['Omentum - 1319',
#   'RNA',
#   'Omentum',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Carcinoma',
#   'Metastatic'],
#  'GSM46835': ['Abdominal wall mass - 1321',
#   'RNA',
#   'Abdominal wall mass',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Carcinoma, NOS',
#   'Metastatic'],
#  'GSM46838': ['R adnexa or metastatic transverse colon nodule - 1350',
#   'RNA',
#   'R adnexa or metastatic transverse colon nodule',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Mucinous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM46839': ['Ovary - 1351',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM137979': ['Uterus - 195190',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM137978': ['Breast - 195189',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM325819': ['liver - 465685',
#   'RNA',
#   'liver',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM325818': ['Ascending Colon - 465682',
#   'RNA',
#   'Ascending Colon',
#   '70-79',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179788': ['Uterus - 187254',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM179789': ['Kidney - 193000',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM179786': ['Lung - 187252',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM179787': ['Ovary - 187253',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Asian',
#   'Ovary',
#   'Clear cell adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179784': ['Lung - 170813',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenosquamous Carcinoma',
#   'Non-metastatic'],
#  'GSM179785': ['Abdominal mass - 187248',
#   'RNA',
#   'Abdominal mass',
#   '60-70',
#   'Female',
#   'African-American',
#   'Corpus Uteri'],
#  'GSM179782': ['Rectum - 127824',
#   'RNA',
#   'Rectum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Rectum',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179783': ['Cervix - 129657',
#   'RNA',
#   'Cervix',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Cervix Uteri',
#   'Squamous cell carcinoma, non-keratinizing',
#   'Non-metastatic'],
#  'GSM179780': ['Breast - 6630',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM179781': ['Pancreas - 78393',
#   'RNA',
#   'Pancreas',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Exocrine Pancreas',
#   'Ductal adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301682': ['Kidney - 433116',
#   'RNA',
#   'Kidney',
#   '50-59',
#   'Male',
#   'Hispanic',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM301683': ['Kidney - 433118',
#   'RNA',
#   'Kidney',
#   '40-49',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM301680': ['Lung - 433111',
#   'RNA',
#   'Lung',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM301681': ['Ovary - 433115',
#   'RNA',
#   'Ovary',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary serous cystadenocarcinoma',
#   'Non-metastatic'],
#  'GSM301686': ['Breast - 438160',
#   'RNA',
#   'Breast',
#   '30-39',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Medullary Carcinoma, NOS',
#   'Non-metastatic'],
#  'GSM301687': ['Kidney - 438162',
#   'RNA',
#   'Kidney',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Cyst-associated renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM301684': ['Uterus - 433124',
#   'RNA',
#   'Uterus',
#   '70-79',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301685': ['Uterus - 433403',
#   'RNA',
#   'Uterus',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301688': ['Breast - 438163',
#   'RNA',
#   'Breast',
#   '80-89',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM301689': ['Chest Wall - 438167',
#   'RNA',
#   'Chest Wall',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM152699': ['Breast - 228536',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM152698': ['Breast - 228533',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM152693': ['Ovary - 226423',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Serous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM152692': ['Colon - 226422',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152691': ['Breast - 226421',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM152690': ['Uterus - 226416',
#   'RNA',
#   'Uterus',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM152697': ['kidney - 228531',
#   'RNA',
#   'kidney',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM152696': ['Uterus - 228530',
#   'RNA',
#   'Uterus',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM152695': ['Colon - 226429',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152694': ['Uterus - 226424',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM203698': ['Thyroid - 309411',
#   'RNA',
#   'Thyroid',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Thyroid',
#   'Medullary carcinoma, NOS',
#   'Non-metastatic'],
#  'GSM203699': ['Lung - 309414',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM203694': ['Kidney - 309394',
#   'RNA',
#   'Kidney',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM203695': ['Axillary lymph node - 309395',
#   'RNA',
#   'Axillary lymph node',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Metastatic Ductal Carcinoma',
#   'Metastatic'],
#  'GSM203696': ['Kidney - 309406',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM203697': ['Kidney - 309410',
#   'RNA',
#   'Kidney',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM203690': ['Breast - 308707',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM203691': ['Colon - 309390',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203692': ['Kidney - 309391',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Hispanic',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM203693': ['Breast - 309393',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53058': ['Endometrium - 1272',
#   'RNA',
#   'Endometrium',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Malignant mixed Mullerian tumor',
#   'Non-metastatic'],
#  'GSM53059': ['Breast - 1290',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53052': ['Breast - 1239',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53053': ['Endometrium - 1240',
#   'RNA',
#   'Endometrium',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53050': ['Uterus - 1236',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Sarcoma, NOS',
#   'Non-metastatic'],
#  'GSM53051': ['Colon - 1237',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'African-American',
#   'Colon',
#   'Adenocarcinoma In situ',
#   'Non-metastatic'],
#  'GSM53056': ['Ovary - 1270',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Metastatic Adenocarcinoma',
#   'Metastatic'],
#  'GSM53057': ['Kidney - 1271',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM53054': ['Ovary - 1241',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53055': ['Colon - 1259',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM277721': ['Uterus - 433390',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM277723': ['Kidney - 433393',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Renal mixed papillary sarcomatoid',
#   'Non-metastatic'],
#  'GSM53128': ['Breast - 31873',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'African-American',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53129': ['Pelvic Tumor - 31875',
#   'RNA',
#   'Pelvic Tumor',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53126': ['Colon - 31852',
#   'RNA',
#   'Colon',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53127': ['Kidney - 31869',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM53124': ['Ovary - 31848',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53125': ['Omentum - 31850',
#   'RNA',
#   'Omentum',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Adenocarcinoma',
#   'Metastatic'],
#  'GSM53122': ['Kidney - 29311',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM53123': ['Breast - 31838',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM53120': ['Uterus - 29305',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53121': ['Ovary - 29308',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Stomach',
#   'Metastatic Signet Ring Cell Carcinoma',
#   'Metastatic'],
#  'GSM46856': ['Rectosigmoid - 22225',
#   'RNA',
#   'Rectosigmoid',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Rectosigmoid',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM38107': ['Colon - 8266',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM38106': ['Breast - 8264',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'American Indian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM38105': ['Colon - 8260',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM38104': ['Lung - 8258',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM38103': ['Lung - 8256',
#   'RNA',
#   'Lung',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM38102': ['Breast - 8254',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM38101': ['Stomach - 8252',
#   'RNA',
#   'Stomach',
#   '70-80',
#   'Female',
#   'Asian',
#   'Stomach'],
#  'GSM38100': ['Lung - 8250',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM38109': ['Breast - 8270',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM38108': ['Liver - 8268',
#   'RNA',
#   'Liver',
#   '50-60',
#   'Female',
#   'American Indian',
#   'Vulva',
#   'Metastatic Squamous cell carcinoma',
#   'Metastatic'],
#  'GSM46857': ['Colon - 22227',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76499': ['Endometrium - 20303',
#   'RNA',
#   'Endometrium',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
# ...
#  'GSM325789': ['Ascending Colon - 345986',
#   'RNA',
#   'Ascending Colon',
#   '80-89',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM325788': ['Breast - 192999',
#   'RNA',
#   'Breast',
#   '80-89',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM46948': ['Ovary - 31836',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Serous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM46949': ['Endometrium - 31840',
#   'RNA',
#   'Endometrium',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM179908': ['Colon - 276669',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM179909': ['Uterus - 276671',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM179900': ['Esophagus - 267119',
#   'RNA',
#   'Esophagus',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Esophagus'],
#  'GSM179901': ['Prostate - 276643',
#   'RNA',
#   'Prostate',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM179902': ['Breast - 276644',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM179903': ['Prostate - 276649',
#   'RNA',
#   'Prostate',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM179904': ['Kidney - 276652',
#   'RNA',
#   'Kidney',
#   '30-40',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM179905': ['Uterus - 276659',
#   'RNA',
#   'Uterus',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM179906': ['Omentum - 276662',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Carcinoma',
#   'Metastatic'],
#  'GSM179907': ['Cervix - 276668',
#   'RNA',
#   'Cervix',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Cervix Uteri',
#   'Squamous cell carcinoma, non-keratinizing',
#   'Non-metastatic'],
#  'GSM301656': ['Colon - 416799',
#   'RNA',
#   'Colon',
#   '80-89',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM301651': ['Breast - 346008',
#   'RNA',
#   'Breast',
#   '60-69',
#   'Male',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM152657': ['Ovary - 209714',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Benign serous cystadenoma of borderline malignancy',
#   'Non-metastatic'],
#  'GSM152656': ['Testis - 209713',
#   'RNA',
#   'Testis',
#   '20-30',
#   'Male',
#   'Caucasian',
#   'Testis',
#   'Mixed germ cell tumor',
#   'Non-metastatic'],
#  'GSM152655': ['Uterus - 209711',
#   'RNA',
#   'Uterus',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Endometrium'],
#  'GSM152654': ['Ovary - 209709',
#   'RNA',
#   'Ovary',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152653': ['Ovary - 209699',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary serous cystadenocarcinoma',
#   'Non-metastatic'],
#  'GSM152652': ['Lung - 209696',
#   'RNA',
#   'Lung',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Lung'],
#  'GSM152651': ['Para aortic tissue - 207539',
#   'RNA',
#   'Para aortic tissue',
#   '20-30',
#   'Male',
#   'Hispanic',
#   'Testis',
#   'Mixed germ cell tumor',
#   'Non-metastatic'],
#  'GSM152650': ['Kidney - 207538',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney'],
#  'GSM203650': ['Uterus - 211376',
#   'RNA',
#   'Uterus',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM203651': ['Uterus - 211382',
#   'RNA',
#   'Uterus',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM203652': ['Hemidiaphragm - 211385',
#   'RNA',
#   'Hemidiaphragm',
#   '70-80',
#   'Male',
#   'Asian',
#   'Retroperitoneum',
#   'Metastatic Dedifferentiated liposarcoma',
#   'Metastatic'],
#  'GSM203653': ['Colon - 211386',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM203654': ['Omentum - 211387',
#   'RNA',
#   'Omentum',
#   '40-50',
#   'Female',
#   'Asian',
#   'Peritoneum'],
#  'GSM203655': ['Kidney - 228541',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM152659': ['Ovary - 209718',
#   'RNA',
#   'Ovary',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM152658': ['Colon - 209717',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117737': ['Endometrium - 184819',
#   'RNA',
#   'Endometrium',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Endometrium'],
#  'GSM117736': ['Retroperitoneal Mass - 184818',
#   'RNA',
#   'Retroperitoneal Mass',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Mucinous Adenocarinoma',
#   'Metastatic'],
#  'GSM53096': ['Breast - 2322',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53097': ['Bladder - 2328',
#   'RNA',
#   'Bladder',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Bladder',
#   'Papillary transitional cell carcinoma',
#   'Non-metastatic'],
#  'GSM53094': ['Breast - 2319',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53095': ['Breast - 2321',
#   'RNA',
#   'Breast',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53092': ['Kidney - 2316',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Papillary renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM53093': ['Corpus Uteri - 2317',
#   'RNA',
#   'Corpus Uteri',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53090': ['Liver - 2313',
#   'RNA',
#   'Liver',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Metastatic Mucinous Carcinoma',
#   'Metastatic'],
#  'GSM53091': ['Breast - 2314',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53098': ['Ovary - 23862',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Mucinous Adenocarinoma',
#   'Non-metastatic'],
#  'GSM53099': ['Breast - 23874',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM277734': ['Breast - 440439',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Invasive Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM277735': ['Kidney - 440442',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM117739': ['Endometrium - 184821',
#   'RNA',
#   'Endometrium',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM117738': ['Colon - 184820',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM277730': ['Stomach - 438174',
#   'RNA',
#   'Stomach',
#   '70-80',
#   'Female',
#   'African-American',
#   'Stomach',
#   'Signet Ring Cell Carcinoma',
#   'Non-metastatic'],
#  'GSM277731': ['Colon - 440432',
#   'RNA',
#   'Colon',
#   '80-90',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM277732': ['ovary - 440433',
#   'RNA',
#   'ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Adenocarcinoma, endometrioid and papillary serous',
#   'Non-metastatic'],
#  'GSM277733': ['Ovary - 440438',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53168': ['Rectum - 4610',
#   'RNA',
#   'Rectum',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Rectum',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53169': ['Colon - 5150',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM53162': ['Prostate - 4337',
#   'RNA',
#   'Prostate',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, Acinar Type',
#   'Non-metastatic'],
#  'GSM53163': ['Ovary - 4342',
#   'RNA',
#   'Ovary',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM53160': ['Breast - 4226',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM53161': ['Breast - 4227',
#   'RNA',
#   'Breast',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Lobular Carcinoma',
#   'Non-metastatic'],
#  'GSM53166': ['Omentum - 4347',
#   'RNA',
#   'Omentum',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Carcinoma',
#   'Metastatic'],
#  'GSM53167': ['Lung - 4451',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Squamous cell carcinoma',
#   'Non-metastatic'],
#  'GSM53164': ['Uterus - 4344',
#   'RNA',
#   'Uterus',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM53165': ['Ovary - 4346',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary Serous Carcinoma',
#   'Non-metastatic'],
#  'GSM203720': ['Soft tissue of arm - 311876',
#   'RNA',
#   'Soft tissue of arm',
#   '70-80',
#   'Male',
#   'African-American',
#   'Soft tissue of arm',
#   'Pleomorphic sarcoma',
#   'Non-metastatic'],
#  'GSM203721': ['Soft Tissue Thigh - 311878',
#   'RNA',
#   'Soft Tissue Thigh',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Soft Tissue Thigh',
#   'Pleomorphic sarcoma',
#   'Non-metastatic'],
#  'GSM203722': ['Prostate - 317475',
#   'RNA',
#   'Prostate',
#   '50-60',
#   'Male',
#   'Asian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM203723': ['Colon - 317481',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma arising in a villous adenoma',
#   'Non-metastatic'],
#  'GSM203724': ['Colon - 341507',
#   'RNA',
#   'Colon',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203725': ['Ovary - 341508',
#   'RNA',
#   'Ovary',
#   '30-40',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Papillary serous tumor of low malignant potential',
#   'Non-metastatic'],
#  'GSM203726': ['Breast - 341510',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM203727': ['Kidney - 341513',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM203728': ['Colon - 341516',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM203729': ['Kidney - 341517',
#   'RNA',
#   'Kidney',
#   '40-50',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM353883': ['Colon - 403721',
#   'RNA',
#   'Colon',
#   '70-79',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM353882': ['Prostate - 403717',
#   'RNA',
#   'Prostate',
#   '70-79',
#   'Male',
#   'Caucasian',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM353881': ['Cecum - 345979',
#   'RNA',
#   'Cecum',
#   '80-89',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Mucinous Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM353887': ['Parotid Lymph Node - 433113',
#   'RNA',
#   'Parotid Lymph Node',
#   '40-49',
#   'Female',
#   'Caucasian',
#   'Melanoma of Skin',
#   'Malignant melanoma, NOS',
#   'Non-metastatic'],
#  'GSM353886': ['Omentum - 433112',
#   'RNA',
#   'Omentum',
#   '60-69',
#   'Female',
#   'Caucasian',
#   'Primary Peritoneum'],
#  'GSM353885': ['Lung - 433110',
#   'RNA',
#   'Lung',
#   '70-79',
#   'Male',
#   'Caucasian',
#   'Lung',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM353884': ['Prostate - 423091',
#   'RNA',
#   'Prostate',
#   '50-59',
#   'Male',
#   'African-American',
#   'Prostate',
#   'Adenocarcinoma, NOS',
#   'Non-metastatic'],
#  'GSM353889': ['Kidney - 433123',
#   'RNA',
#   'Kidney',
#   '70-79',
#   'Male',
#   'Caucasian',
#   'Kidney',
#   'Clear Cell Renal Carcinoma',
#   'Non-metastatic'],
#  'GSM353888': ['Uterus - 433119',
#   'RNA',
#   'Uterus',
#   '50-59',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM76619': ['Breast - 6300',
#   'RNA',
#   'Breast',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76618': ['Colon - 6295',
#   'RNA',
#   'Colon',
#   '80-90',
#   'Male',
#   'African-American',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76611': ['Colon - 58992',
#   'RNA',
#   'Colon',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76610': ['Colon - 58991',
#   'RNA',
#   'Colon',
#   '30-40',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76613': ['Breast - 59000',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'African-American',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM76612': ['Thyroid - 58999',
#   'RNA',
#   'Thyroid',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Thyroid',
#   'Papillary carcinoma, follicular variant',
#   'Non-metastatic'],
#  'GSM76615': ['Colon - 59003',
#   'RNA',
#   'Colon',
#   '50-60',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76614': ['Cervix - 59002',
#   'RNA',
#   'Cervix',
#   '40-50',
#   'Female',
#   'Caucasian',
#   'Cervix Uteri',
#   'Squamous cell carcinoma, non-keratinizing',
#   'Non-metastatic'],
#  'GSM76617': ['Colon - 6293',
#   'RNA',
#   'Colon',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  'GSM76616': ['Omentum - 6292',
#   'RNA',
#   'Omentum',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Metastatic Papillary Serous Adenocarcinoma',
#   'Metastatic'],
#  'GSM117694': ['Kidney - 161520',
#   'RNA',
#   'Kidney',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Adenocarcinoma, clear cell type',
#   'Non-metastatic'],
#  'GSM117695': ['Breast - 161521',
#   'RNA',
#   'Breast',
#   '70-80',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117719': ['Breast - 174937',
#   'RNA',
#   'Breast',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Breast',
#   'Ductal Carcinoma',
#   'Non-metastatic'],
#  'GSM117718': ['Ovary - 174936',
#   'RNA',
#   'Ovary',
#   '50-60',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Clear cell adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117715': ['Kidney - 174064',
#   'RNA',
#   'Kidney',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Conventional (clear cell) renal carcinoma',
#   'Non-metastatic'],
#  'GSM117714': ['Lung - 174063',
#   'RNA',
#   'Lung',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Lung',
#   'Neuroendocrine carcinoma',
#   'Non-metastatic'],
#  'GSM117717': ['Omentum - 174934',
#   'RNA',
#   'Omentum',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Peritoneum'],
#  'GSM117716': ['Ovary - 174931',
#   'RNA',
#   'Ovary',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Ovary',
#   'Clear cell adenocarcinoma',
#   'Non-metastatic'],
#  'GSM117711': ['Kidney - 174058',
#   'RNA',
#   'Kidney',
#   '80-90',
#   'Female',
#   'Caucasian',
#   'Kidney',
#   'Renal cell carcinoma',
#   'Non-metastatic'],
#  'GSM117710': ['Rectum - 174057',
#   'RNA',
#   'Rectum',
#   '70-80',
#   'Male',
#   'Caucasian',
#   'Rectum',
#   'Mucinous Carcinoma',
#   'Non-metastatic'],
#  'GSM117713': ['Renal pelvis - 174062',
#   'RNA',
#   'Renal pelvis',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Renal Pelvis and Ureter',
#   'Papillary transitional cell carcinoma',
#   'Non-metastatic'],
#  'GSM117712': ['Endometrium - 174059',
#   'RNA',
#   'Endometrium',
#   '60-70',
#   'Female',
#   'Caucasian',
#   'Endometrium',
#   'Endometrioid carcinoma',
#   'Non-metastatic'],
#  'GSM38077': ['Colon - 8200',
#   'RNA',
#   'Rectosigmoid',
#   '60-70',
#   'Male',
#   'Caucasian',
#   'Colon',
#   'Adenocarcinoma',
#   'Non-metastatic'],
#  ...}

# %%
f = open("tmp", 'w')
print >>f, '\t'.join(header)
for i in samples:
    s = [i]
    for j in dict[i]:
        s.append(j)
    print >>f, '\t'.join(s)

# %%
clinical = []
sample = 0
top = []
for line in data:
    if "^SAMPLE" in line:
        if sample == True:
            top.append("\t".join([sample_id, clinical[-1]]))
            sample = False
            clinical = []
        sample_id = line.rstrip('\n').split(' = ')[-1]
    elif "Clinical Value" in line:
        clinical.append(line.rstrip("\n").split(": ")[-1])
        sample = True

# %%
for i in top:
    print(i)
# Out:
# GSM38069	Epithelioid leiomyosarcoma
# GSM38101	Gastrointestinal stromal tumor
# GSM46821	Metastatic Adenocarcinoma
# GSM46872	Papillary transitional cell carcinoma
# GSM46903	Metastatic Mucinous adenocarcinoma consistent with gastrointestinal carcinoma
# GSM46911	Papillary serous tumor of low malignant potential
# GSM46926	Ewing's sarcoma
# GSM53041	Metastatic Leiomyosarcoma
# GSM53044	Neuroendocrine carcinoma, NOS
# GSM53046	No AJCC Staging Scheme For this Histology/Site
# GSM53188	Oncocytoma
# GSM76498	No
# GSM76624	3
# GSM76634	No AJCC Staging Scheme
# GSM89031	No AJCC Staging Scheme
# GSM89035	No
# GSM102483	Adult Granulosa Cell Tumor
# GSM102503	Hepatocellular carcinoma
# GSM117587	Glioblastoma multiformae
# GSM117591	Cellular Schwannoma
# GSM117657	Hepatocellular carcinoma
# GSM117666	Leiomyosarcoma
# GSM117668	Metastatic Signet ring cell adenocarcinoma
# GSM117690	Metastatic Squamous cell carcinoma
# GSM117740	Metastatic Carcinoma, NOS
# GSM117754	Oncocytoma
# GSM117755	Gastrointestinal Stromal Tumor (GIST)
# GSM137899	Metastatic Gastrointestinal stromal tumor
# GSM137915	Metastatic Papillary serous carcinoma
# GSM137920	Metastatic Leiomyosarcoma
# GSM137940	Gastrointestinal stromal tumor, benign
# GSM137946	Renal oncocytoma
# GSM137957	Endometrioid tumor of low malignant potential
# GSM137962	Hepatocellular Carcinoma
# GSM137977	Malignant renal oncocytoma
# GSM152593	Renal oncocytoma
# GSM152650	Angiomyolipoma
# GSM152655	Leiomyosarcoma
# GSM152777	Anaplastic large cell lymphoma, primary cutaneous type
# GSM179796	Gastrointestinal stromal tumor, uncertain malignant potential
# GSM179818	Metastatic Squamous cell carcinoma
# GSM179826	Leiomyosarcoma
# GSM179916	Ependymoma, myxopapillary
# GSM179939	Leiomyosarcoma
# GSM179952	Hepatocellular Carcinoma
# GSM203660	Cholangiocarcinoma
# GSM203678	Pheochromocytoma
# GSM203689	Metastatic Keratinizing Squamous Cell Carcinoma
# GSM203751	Hepatocellular Carcinoma
# GSM203757	Metastatic Malignant Mixed Mullerian Tumor
# GSM203794	Metastatic Mucinous adenocarcinoma
# GSM231890	Hepatocellular carcinoma
# GSM231941	Solitary fibrous tumor, benign
# GSM277720	Cholangiocarcinoma
# GSM301700	Serous Adenocarcinoma
# GSM325800	Hepatocellular Carcinoma
# GSM325805	Metastatic Adenocarcinoma
# GSM325821	Astrocytoma
# GSM353900	Mantle Cell Lymphoma
